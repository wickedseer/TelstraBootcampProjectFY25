# %%
# !pip install kafka-python
# Out:
# Requirement already satisfied: kafka-python in /usr/local/lib/python3.10/dist-packages (2.0.2)

# %%
import pandas as pd
import numpy as np
import time
import random
from datetime import datetime, timedelta
from kafka import KafkaProducer
import json


KAFKA_BROKER = '13.201.228.245:9092'
KAFKA_TOPIC = 'roro1'
producer = KafkaProducer(bootstrap_servers=KAFKA_BROKER, value_serializer=lambda v: json.dumps(v).encode('utf-8'))

device_ids = [f'Router_{i}' for i in range(1, 6)]
customer_ids = [f'Customer_{i}' for i in range(1, 21)]
location_ids = [f'Location_{i}' for i in range(1, 4)]

# Function to introduce anomalies (e.g., None values) in the data
def introduce_anomalies(data):
    # Randomly introduce None values for certain fields
    if random.random() < 0.1:  # 10% chance to make Signal_Strength None
        data["Signal_Strength"] = None
    if random.random() < 0.05:  # 5% chance to make Data_Transfer_Rate None
        data["Data_Transfer_Rate"] = None
    if random.random() < 0.05:  # 5% chance to make Call_Drop_Rate None
        data["Call_Drop_Rate"] = None
    if random.random() < 0.03:  # 3% chance to make Timestamp None
        data["Timestamp"] = None
    return data

try:
    while True:
        # Generate initial data
        signal_strength = np.random.randint(-110, -29)  # Signal strength in dBm
        data_transfer_speed = np.random.randint(1, 1001)  # Data transfer rate in Mbps
        call_drop_rate = np.random.uniform(0, 1)  # Call drop rate in percentage (0 to 1)

        # Correlate lower signal strength with higher call drop rates and slower data speeds
        if signal_strength < -70:
            data_transfer_speed -= random.uniform(50, 150)  # Reduce data speed when signal is weak
            call_drop_rate += random.uniform(0.2, 0.5)  # Increase call drop rate when signal is weak

        # Ensure no negative or overly high values after adjustments
        data_transfer_speed = max(1, data_transfer_speed)  # Ensure speed is at least 1 Mbps
        call_drop_rate = min(1, max(0, call_drop_rate))  # Ensure call drop rate is between 0 and 1

        # Construct the data message
        data = {

            "Customer_ID": random.choice(customer_ids),
            "Device_ID": random.choice(device_ids),
            "Timestamp": datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
            "Signal_Strength": signal_strength,
            "Call_Drop_Rate": call_drop_rate,
            "Data_Transfer_Rate": data_transfer_speed,
            "Latency": np.random.randint(1, 250),  # Latency in milliseconds
            "Location_ID": random.choice(location_ids),
        }

        # Introduce anomalies, including the possibility of making Timestamp None
        data = introduce_anomalies(data)

        # Print and send the data to Kafka
        print(data)
        producer.send(KAFKA_TOPIC, value=data)
        print(f"Sent data to Kafka: {data}")

        # Wait before sending the next data point
        time.sleep(1)

except KeyboardInterrupt:
    print("Live data generation stopped.")

finally:
    producer.close()
# Out:
# {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:55:43', 'Signal_Strength': -63, 'Call_Drop_Rate': None, 'Data_Transfer_Rate': 53, 'Latency': 248, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:55:43', 'Signal_Strength': -63, 'Call_Drop_Rate': None, 'Data_Transfer_Rate': 53, 'Latency': 248, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:55:44', 'Signal_Strength': -65, 'Call_Drop_Rate': 0.027591918477896882, 'Data_Transfer_Rate': 246, 'Latency': 169, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:55:44', 'Signal_Strength': -65, 'Call_Drop_Rate': 0.027591918477896882, 'Data_Transfer_Rate': 246, 'Latency': 169, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_9', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:55:45', 'Signal_Strength': -82, 'Call_Drop_Rate': 0.7136908459121243, 'Data_Transfer_Rate': 476.2914220072575, 'Latency': 199, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_9', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:55:45', 'Signal_Strength': -82, 'Call_Drop_Rate': 0.7136908459121243, 'Data_Transfer_Rate': 476.2914220072575, 'Latency': 199, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:55:46', 'Signal_Strength': -67, 'Call_Drop_Rate': 0.1797074217134903, 'Data_Transfer_Rate': 171, 'Latency': 195, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:55:46', 'Signal_Strength': -67, 'Call_Drop_Rate': 0.1797074217134903, 'Data_Transfer_Rate': 171, 'Latency': 195, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_8', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:55:47', 'Signal_Strength': -56, 'Call_Drop_Rate': 0.9912290656219087, 'Data_Transfer_Rate': 532, 'Latency': 137, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_8', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:55:47', 'Signal_Strength': -56, 'Call_Drop_Rate': 0.9912290656219087, 'Data_Transfer_Rate': 532, 'Latency': 137, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:55:48', 'Signal_Strength': -63, 'Call_Drop_Rate': 0.8560826218337231, 'Data_Transfer_Rate': 411, 'Latency': 203, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:55:48', 'Signal_Strength': -63, 'Call_Drop_Rate': 0.8560826218337231, 'Data_Transfer_Rate': 411, 'Latency': 203, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:55:49', 'Signal_Strength': -76, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 1, 'Latency': 63, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:55:49', 'Signal_Strength': -76, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 1, 'Latency': 63, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:55:50', 'Signal_Strength': -42, 'Call_Drop_Rate': 0.6122497625939202, 'Data_Transfer_Rate': 974, 'Latency': 215, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:55:50', 'Signal_Strength': -42, 'Call_Drop_Rate': 0.6122497625939202, 'Data_Transfer_Rate': 974, 'Latency': 215, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_1', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:55:51', 'Signal_Strength': None, 'Call_Drop_Rate': 0.9828543748098815, 'Data_Transfer_Rate': 176.5316267743315, 'Latency': 74, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_1', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:55:51', 'Signal_Strength': None, 'Call_Drop_Rate': 0.9828543748098815, 'Data_Transfer_Rate': 176.5316267743315, 'Latency': 74, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_13', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:55:52', 'Signal_Strength': -43, 'Call_Drop_Rate': 0.017642764328565486, 'Data_Transfer_Rate': 293, 'Latency': 90, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_13', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:55:52', 'Signal_Strength': -43, 'Call_Drop_Rate': 0.017642764328565486, 'Data_Transfer_Rate': 293, 'Latency': 90, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_20', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:55:53', 'Signal_Strength': -98, 'Call_Drop_Rate': 0.6291919562693187, 'Data_Transfer_Rate': 351.8831862188881, 'Latency': 141, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_20', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:55:53', 'Signal_Strength': -98, 'Call_Drop_Rate': 0.6291919562693187, 'Data_Transfer_Rate': 351.8831862188881, 'Latency': 141, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_19', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:55:54', 'Signal_Strength': -39, 'Call_Drop_Rate': 0.25466273599318245, 'Data_Transfer_Rate': 915, 'Latency': 28, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_19', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:55:54', 'Signal_Strength': -39, 'Call_Drop_Rate': 0.25466273599318245, 'Data_Transfer_Rate': 915, 'Latency': 28, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:55:55', 'Signal_Strength': None, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 67.04323851692945, 'Latency': 221, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:55:55', 'Signal_Strength': None, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 67.04323851692945, 'Latency': 221, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_3', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:55:56', 'Signal_Strength': None, 'Call_Drop_Rate': 0.5275521351350773, 'Data_Transfer_Rate': 643, 'Latency': 133, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_3', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:55:56', 'Signal_Strength': None, 'Call_Drop_Rate': 0.5275521351350773, 'Data_Transfer_Rate': 643, 'Latency': 133, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_8', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:55:57', 'Signal_Strength': None, 'Call_Drop_Rate': None, 'Data_Transfer_Rate': 233.20064849826082, 'Latency': 212, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_8', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:55:57', 'Signal_Strength': None, 'Call_Drop_Rate': None, 'Data_Transfer_Rate': 233.20064849826082, 'Latency': 212, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_3', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:55:58', 'Signal_Strength': -69, 'Call_Drop_Rate': 0.19667209441004774, 'Data_Transfer_Rate': 269, 'Latency': 102, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_3', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:55:58', 'Signal_Strength': -69, 'Call_Drop_Rate': 0.19667209441004774, 'Data_Transfer_Rate': 269, 'Latency': 102, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:55:59', 'Signal_Strength': -88, 'Call_Drop_Rate': None, 'Data_Transfer_Rate': None, 'Latency': 247, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:55:59', 'Signal_Strength': -88, 'Call_Drop_Rate': None, 'Data_Transfer_Rate': None, 'Latency': 247, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_7', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:56:00', 'Signal_Strength': -31, 'Call_Drop_Rate': 0.9623202520257852, 'Data_Transfer_Rate': 796, 'Latency': 154, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_7', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:56:00', 'Signal_Strength': -31, 'Call_Drop_Rate': 0.9623202520257852, 'Data_Transfer_Rate': 796, 'Latency': 154, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:01', 'Signal_Strength': -74, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 471.8252743555242, 'Latency': 145, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:01', 'Signal_Strength': -74, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 471.8252743555242, 'Latency': 145, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_5', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:02', 'Signal_Strength': -106, 'Call_Drop_Rate': 0.7525671207603057, 'Data_Transfer_Rate': 335.71261276818086, 'Latency': 151, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_5', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:02', 'Signal_Strength': -106, 'Call_Drop_Rate': 0.7525671207603057, 'Data_Transfer_Rate': 335.71261276818086, 'Latency': 151, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:03', 'Signal_Strength': None, 'Call_Drop_Rate': 0.19214227787279547, 'Data_Transfer_Rate': 721, 'Latency': 246, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:03', 'Signal_Strength': None, 'Call_Drop_Rate': 0.19214227787279547, 'Data_Transfer_Rate': 721, 'Latency': 246, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_7', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:04', 'Signal_Strength': -61, 'Call_Drop_Rate': 0.8976341009698409, 'Data_Transfer_Rate': 413, 'Latency': 43, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_7', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:04', 'Signal_Strength': -61, 'Call_Drop_Rate': 0.8976341009698409, 'Data_Transfer_Rate': 413, 'Latency': 43, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:05', 'Signal_Strength': -91, 'Call_Drop_Rate': 0.8607957934703235, 'Data_Transfer_Rate': 852.8822801263175, 'Latency': 149, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:05', 'Signal_Strength': -91, 'Call_Drop_Rate': 0.8607957934703235, 'Data_Transfer_Rate': 852.8822801263175, 'Latency': 149, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:06', 'Signal_Strength': -105, 'Call_Drop_Rate': 0.41124882053257333, 'Data_Transfer_Rate': 140.22517027252195, 'Latency': 79, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:06', 'Signal_Strength': -105, 'Call_Drop_Rate': 0.41124882053257333, 'Data_Transfer_Rate': 140.22517027252195, 'Latency': 79, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_20', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:07', 'Signal_Strength': -80, 'Call_Drop_Rate': 0.9625695217185356, 'Data_Transfer_Rate': 233.96103358300883, 'Latency': 6, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_20', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:07', 'Signal_Strength': -80, 'Call_Drop_Rate': 0.9625695217185356, 'Data_Transfer_Rate': 233.96103358300883, 'Latency': 6, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_9', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:08', 'Signal_Strength': -37, 'Call_Drop_Rate': 0.3360518881889337, 'Data_Transfer_Rate': 603, 'Latency': 158, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_9', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:08', 'Signal_Strength': -37, 'Call_Drop_Rate': 0.3360518881889337, 'Data_Transfer_Rate': 603, 'Latency': 158, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_4', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:09', 'Signal_Strength': -51, 'Call_Drop_Rate': 0.1995515870438037, 'Data_Transfer_Rate': 115, 'Latency': 159, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_4', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:09', 'Signal_Strength': -51, 'Call_Drop_Rate': 0.1995515870438037, 'Data_Transfer_Rate': 115, 'Latency': 159, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_20', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:56:10', 'Signal_Strength': -69, 'Call_Drop_Rate': 0.888257693080167, 'Data_Transfer_Rate': 969, 'Latency': 104, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_20', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:56:10', 'Signal_Strength': -69, 'Call_Drop_Rate': 0.888257693080167, 'Data_Transfer_Rate': 969, 'Latency': 104, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:11', 'Signal_Strength': None, 'Call_Drop_Rate': None, 'Data_Transfer_Rate': 1, 'Latency': 79, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:11', 'Signal_Strength': None, 'Call_Drop_Rate': None, 'Data_Transfer_Rate': 1, 'Latency': 79, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_15', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:12', 'Signal_Strength': -84, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': None, 'Latency': 234, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_15', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:12', 'Signal_Strength': -84, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': None, 'Latency': 234, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_9', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:13', 'Signal_Strength': -33, 'Call_Drop_Rate': 0.9805802555382986, 'Data_Transfer_Rate': None, 'Latency': 241, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_9', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:13', 'Signal_Strength': -33, 'Call_Drop_Rate': 0.9805802555382986, 'Data_Transfer_Rate': None, 'Latency': 241, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_9', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:14', 'Signal_Strength': -95, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 1, 'Latency': 15, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_9', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:14', 'Signal_Strength': -95, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 1, 'Latency': 15, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:15', 'Signal_Strength': -78, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 1, 'Latency': 72, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:15', 'Signal_Strength': -78, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 1, 'Latency': 72, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_6', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:16', 'Signal_Strength': -48, 'Call_Drop_Rate': 0.9854772447119237, 'Data_Transfer_Rate': 675, 'Latency': 58, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_6', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:16', 'Signal_Strength': -48, 'Call_Drop_Rate': 0.9854772447119237, 'Data_Transfer_Rate': 675, 'Latency': 58, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_20', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:17', 'Signal_Strength': -94, 'Call_Drop_Rate': 0.5766293848570982, 'Data_Transfer_Rate': 252.66238941565302, 'Latency': 246, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_20', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:17', 'Signal_Strength': -94, 'Call_Drop_Rate': 0.5766293848570982, 'Data_Transfer_Rate': 252.66238941565302, 'Latency': 246, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:18', 'Signal_Strength': -101, 'Call_Drop_Rate': 0.7537486774036218, 'Data_Transfer_Rate': 521.5922290986871, 'Latency': 67, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:18', 'Signal_Strength': -101, 'Call_Drop_Rate': 0.7537486774036218, 'Data_Transfer_Rate': 521.5922290986871, 'Latency': 67, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_20', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:19', 'Signal_Strength': -31, 'Call_Drop_Rate': 0.5469501941471528, 'Data_Transfer_Rate': 733, 'Latency': 61, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_20', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:19', 'Signal_Strength': -31, 'Call_Drop_Rate': 0.5469501941471528, 'Data_Transfer_Rate': 733, 'Latency': 61, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_1', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:20', 'Signal_Strength': -52, 'Call_Drop_Rate': 0.05906437699283196, 'Data_Transfer_Rate': 336, 'Latency': 179, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_1', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:20', 'Signal_Strength': -52, 'Call_Drop_Rate': 0.05906437699283196, 'Data_Transfer_Rate': 336, 'Latency': 179, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_14', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:21', 'Signal_Strength': -61, 'Call_Drop_Rate': 0.08592975683705117, 'Data_Transfer_Rate': 854, 'Latency': 249, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_14', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:21', 'Signal_Strength': -61, 'Call_Drop_Rate': 0.08592975683705117, 'Data_Transfer_Rate': 854, 'Latency': 249, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_8', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:22', 'Signal_Strength': None, 'Call_Drop_Rate': 0.458101087932943, 'Data_Transfer_Rate': 366, 'Latency': 36, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_8', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:22', 'Signal_Strength': None, 'Call_Drop_Rate': 0.458101087932943, 'Data_Transfer_Rate': 366, 'Latency': 36, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_7', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:23', 'Signal_Strength': -32, 'Call_Drop_Rate': 0.3840704839063399, 'Data_Transfer_Rate': 991, 'Latency': 104, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_7', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:23', 'Signal_Strength': -32, 'Call_Drop_Rate': 0.3840704839063399, 'Data_Transfer_Rate': 991, 'Latency': 104, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_19', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:24', 'Signal_Strength': -69, 'Call_Drop_Rate': 0.16074053897629925, 'Data_Transfer_Rate': None, 'Latency': 8, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_19', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:24', 'Signal_Strength': -69, 'Call_Drop_Rate': 0.16074053897629925, 'Data_Transfer_Rate': None, 'Latency': 8, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:25', 'Signal_Strength': -45, 'Call_Drop_Rate': 0.7480589263535762, 'Data_Transfer_Rate': 637, 'Latency': 200, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:25', 'Signal_Strength': -45, 'Call_Drop_Rate': 0.7480589263535762, 'Data_Transfer_Rate': 637, 'Latency': 200, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_11', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:26', 'Signal_Strength': -92, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 170.8848471820655, 'Latency': 183, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_11', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:26', 'Signal_Strength': -92, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 170.8848471820655, 'Latency': 183, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_13', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:56:27', 'Signal_Strength': -74, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 463.57110103255167, 'Latency': 75, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_13', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:56:27', 'Signal_Strength': -74, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 463.57110103255167, 'Latency': 75, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_6', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:28', 'Signal_Strength': -106, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 168.62113443704516, 'Latency': 117, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_6', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:28', 'Signal_Strength': -106, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 168.62113443704516, 'Latency': 117, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_6', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:56:29', 'Signal_Strength': -63, 'Call_Drop_Rate': 0.3237659544633523, 'Data_Transfer_Rate': 469, 'Latency': 49, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_6', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:56:29', 'Signal_Strength': -63, 'Call_Drop_Rate': 0.3237659544633523, 'Data_Transfer_Rate': 469, 'Latency': 49, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_6', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:30', 'Signal_Strength': None, 'Call_Drop_Rate': 0.9559132599055548, 'Data_Transfer_Rate': 616.0262965631491, 'Latency': 124, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_6', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:30', 'Signal_Strength': None, 'Call_Drop_Rate': 0.9559132599055548, 'Data_Transfer_Rate': 616.0262965631491, 'Latency': 124, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_6', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:31', 'Signal_Strength': -96, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 219.83504063064203, 'Latency': 70, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_6', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:31', 'Signal_Strength': -96, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 219.83504063064203, 'Latency': 70, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:32', 'Signal_Strength': -32, 'Call_Drop_Rate': 0.5239171449896902, 'Data_Transfer_Rate': 760, 'Latency': 185, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:32', 'Signal_Strength': -32, 'Call_Drop_Rate': 0.5239171449896902, 'Data_Transfer_Rate': 760, 'Latency': 185, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_4', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:33', 'Signal_Strength': -57, 'Call_Drop_Rate': 0.2454404336589242, 'Data_Transfer_Rate': 144, 'Latency': 191, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_4', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:33', 'Signal_Strength': -57, 'Call_Drop_Rate': 0.2454404336589242, 'Data_Transfer_Rate': 144, 'Latency': 191, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_20', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:34', 'Signal_Strength': -61, 'Call_Drop_Rate': 0.8252085876131764, 'Data_Transfer_Rate': 133, 'Latency': 46, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_20', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:34', 'Signal_Strength': -61, 'Call_Drop_Rate': 0.8252085876131764, 'Data_Transfer_Rate': 133, 'Latency': 46, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_4', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:35', 'Signal_Strength': -57, 'Call_Drop_Rate': 0.5365715315995059, 'Data_Transfer_Rate': 678, 'Latency': 15, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_4', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:35', 'Signal_Strength': -57, 'Call_Drop_Rate': 0.5365715315995059, 'Data_Transfer_Rate': 678, 'Latency': 15, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_13', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:36', 'Signal_Strength': -49, 'Call_Drop_Rate': 0.7181911045343494, 'Data_Transfer_Rate': 891, 'Latency': 34, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_13', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:36', 'Signal_Strength': -49, 'Call_Drop_Rate': 0.7181911045343494, 'Data_Transfer_Rate': 891, 'Latency': 34, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_14', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:37', 'Signal_Strength': -65, 'Call_Drop_Rate': 0.9779924306825138, 'Data_Transfer_Rate': 856, 'Latency': 107, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_14', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:37', 'Signal_Strength': -65, 'Call_Drop_Rate': 0.9779924306825138, 'Data_Transfer_Rate': 856, 'Latency': 107, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_8', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:38', 'Signal_Strength': -43, 'Call_Drop_Rate': 0.16768387647552196, 'Data_Transfer_Rate': 926, 'Latency': 203, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_8', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:38', 'Signal_Strength': -43, 'Call_Drop_Rate': 0.16768387647552196, 'Data_Transfer_Rate': 926, 'Latency': 203, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_14', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:56:39', 'Signal_Strength': -30, 'Call_Drop_Rate': 0.23359635494971265, 'Data_Transfer_Rate': 665, 'Latency': 30, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_14', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:56:39', 'Signal_Strength': -30, 'Call_Drop_Rate': 0.23359635494971265, 'Data_Transfer_Rate': 665, 'Latency': 30, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_12', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:40', 'Signal_Strength': -64, 'Call_Drop_Rate': 0.8992044617958433, 'Data_Transfer_Rate': 925, 'Latency': 60, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_12', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:40', 'Signal_Strength': -64, 'Call_Drop_Rate': 0.8992044617958433, 'Data_Transfer_Rate': 925, 'Latency': 60, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_7', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:41', 'Signal_Strength': -82, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': None, 'Latency': 195, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_7', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:41', 'Signal_Strength': -82, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': None, 'Latency': 195, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_7', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:42', 'Signal_Strength': -56, 'Call_Drop_Rate': 0.6169401835740793, 'Data_Transfer_Rate': 769, 'Latency': 86, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_7', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:42', 'Signal_Strength': -56, 'Call_Drop_Rate': 0.6169401835740793, 'Data_Transfer_Rate': 769, 'Latency': 86, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_5', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:43', 'Signal_Strength': -107, 'Call_Drop_Rate': 0.3343677363215421, 'Data_Transfer_Rate': 26.974793933655207, 'Latency': 205, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_5', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:43', 'Signal_Strength': -107, 'Call_Drop_Rate': 0.3343677363215421, 'Data_Transfer_Rate': 26.974793933655207, 'Latency': 205, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_13', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:44', 'Signal_Strength': -94, 'Call_Drop_Rate': 0.3445103333859721, 'Data_Transfer_Rate': 668.5736772717864, 'Latency': 96, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_13', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:44', 'Signal_Strength': -94, 'Call_Drop_Rate': 0.3445103333859721, 'Data_Transfer_Rate': 668.5736772717864, 'Latency': 96, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_9', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:45', 'Signal_Strength': -96, 'Call_Drop_Rate': 0.9541876251881886, 'Data_Transfer_Rate': 651.6753930981056, 'Latency': 80, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_9', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:45', 'Signal_Strength': -96, 'Call_Drop_Rate': 0.9541876251881886, 'Data_Transfer_Rate': 651.6753930981056, 'Latency': 80, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:46', 'Signal_Strength': -92, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 396.1277304465645, 'Latency': 42, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:46', 'Signal_Strength': -92, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 396.1277304465645, 'Latency': 42, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:56:47', 'Signal_Strength': None, 'Call_Drop_Rate': 0.2679047281965658, 'Data_Transfer_Rate': 836.9896659788504, 'Latency': 81, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:56:47', 'Signal_Strength': None, 'Call_Drop_Rate': 0.2679047281965658, 'Data_Transfer_Rate': 836.9896659788504, 'Latency': 81, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_14', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:48', 'Signal_Strength': -66, 'Call_Drop_Rate': 0.9074113803107964, 'Data_Transfer_Rate': 879, 'Latency': 31, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_14', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:48', 'Signal_Strength': -66, 'Call_Drop_Rate': 0.9074113803107964, 'Data_Transfer_Rate': 879, 'Latency': 31, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:49', 'Signal_Strength': -32, 'Call_Drop_Rate': 0.10824872424184184, 'Data_Transfer_Rate': 187, 'Latency': 12, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:49', 'Signal_Strength': -32, 'Call_Drop_Rate': 0.10824872424184184, 'Data_Transfer_Rate': 187, 'Latency': 12, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_8', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:50', 'Signal_Strength': -69, 'Call_Drop_Rate': 0.6541598102778815, 'Data_Transfer_Rate': 462, 'Latency': 94, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_8', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:56:50', 'Signal_Strength': -69, 'Call_Drop_Rate': 0.6541598102778815, 'Data_Transfer_Rate': 462, 'Latency': 94, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:51', 'Signal_Strength': -41, 'Call_Drop_Rate': 0.4303124248313408, 'Data_Transfer_Rate': 415, 'Latency': 9, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:51', 'Signal_Strength': -41, 'Call_Drop_Rate': 0.4303124248313408, 'Data_Transfer_Rate': 415, 'Latency': 9, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_13', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:52', 'Signal_Strength': -65, 'Call_Drop_Rate': 0.8077190799801652, 'Data_Transfer_Rate': 376, 'Latency': 236, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_13', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:52', 'Signal_Strength': -65, 'Call_Drop_Rate': 0.8077190799801652, 'Data_Transfer_Rate': 376, 'Latency': 236, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:53', 'Signal_Strength': -30, 'Call_Drop_Rate': None, 'Data_Transfer_Rate': 760, 'Latency': 75, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:53', 'Signal_Strength': -30, 'Call_Drop_Rate': None, 'Data_Transfer_Rate': 760, 'Latency': 75, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_11', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:54', 'Signal_Strength': -95, 'Call_Drop_Rate': 0.4401709662251289, 'Data_Transfer_Rate': 1, 'Latency': 86, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_11', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:54', 'Signal_Strength': -95, 'Call_Drop_Rate': 0.4401709662251289, 'Data_Transfer_Rate': 1, 'Latency': 86, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_19', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:55', 'Signal_Strength': -77, 'Call_Drop_Rate': 0.9134012145445862, 'Data_Transfer_Rate': 568.8372268023743, 'Latency': 91, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_19', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:56:55', 'Signal_Strength': -77, 'Call_Drop_Rate': 0.9134012145445862, 'Data_Transfer_Rate': 568.8372268023743, 'Latency': 91, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_11', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:56', 'Signal_Strength': -89, 'Call_Drop_Rate': 0.6582918081767228, 'Data_Transfer_Rate': 609.1661910914302, 'Latency': 32, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_11', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:56', 'Signal_Strength': -89, 'Call_Drop_Rate': 0.6582918081767228, 'Data_Transfer_Rate': 609.1661910914302, 'Latency': 32, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:56:57', 'Signal_Strength': -78, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 15.824272018367395, 'Latency': 29, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:56:57', 'Signal_Strength': -78, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 15.824272018367395, 'Latency': 29, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_5', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:58', 'Signal_Strength': None, 'Call_Drop_Rate': 0.7256254368895503, 'Data_Transfer_Rate': 309.16794005578475, 'Latency': 78, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_5', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:56:58', 'Signal_Strength': None, 'Call_Drop_Rate': 0.7256254368895503, 'Data_Transfer_Rate': 309.16794005578475, 'Latency': 78, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_11', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:59', 'Signal_Strength': -99, 'Call_Drop_Rate': 0.38067932798641413, 'Data_Transfer_Rate': None, 'Latency': 240, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_11', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:56:59', 'Signal_Strength': -99, 'Call_Drop_Rate': 0.38067932798641413, 'Data_Transfer_Rate': None, 'Latency': 240, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_14', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:57:00', 'Signal_Strength': -55, 'Call_Drop_Rate': 0.8387346464995594, 'Data_Transfer_Rate': 818, 'Latency': 64, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_14', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:57:00', 'Signal_Strength': -55, 'Call_Drop_Rate': 0.8387346464995594, 'Data_Transfer_Rate': 818, 'Latency': 64, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_1', 'Timestamp': None, 'Signal_Strength': -98, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 302.09415905487253, 'Latency': 197, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_1', 'Timestamp': None, 'Signal_Strength': -98, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 302.09415905487253, 'Latency': 197, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_7', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:57:02', 'Signal_Strength': -79, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 771.0388932444853, 'Latency': 8, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_7', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:57:02', 'Signal_Strength': -79, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 771.0388932444853, 'Latency': 8, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_12', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:57:03', 'Signal_Strength': -75, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 677.4537520327389, 'Latency': 37, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_12', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:57:03', 'Signal_Strength': -75, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 677.4537520327389, 'Latency': 37, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_9', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:57:04', 'Signal_Strength': None, 'Call_Drop_Rate': 0.49617281988160133, 'Data_Transfer_Rate': 360, 'Latency': 124, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_9', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:57:04', 'Signal_Strength': None, 'Call_Drop_Rate': 0.49617281988160133, 'Data_Transfer_Rate': 360, 'Latency': 124, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:57:05', 'Signal_Strength': -54, 'Call_Drop_Rate': 0.4309130871047838, 'Data_Transfer_Rate': 267, 'Latency': 32, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:57:05', 'Signal_Strength': -54, 'Call_Drop_Rate': 0.4309130871047838, 'Data_Transfer_Rate': 267, 'Latency': 32, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:57:06', 'Signal_Strength': -55, 'Call_Drop_Rate': 0.5677883573378798, 'Data_Transfer_Rate': 472, 'Latency': 146, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:57:06', 'Signal_Strength': -55, 'Call_Drop_Rate': 0.5677883573378798, 'Data_Transfer_Rate': 472, 'Latency': 146, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_8', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:57:07', 'Signal_Strength': -34, 'Call_Drop_Rate': 0.2750056645728348, 'Data_Transfer_Rate': 429, 'Latency': 89, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_8', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:57:07', 'Signal_Strength': -34, 'Call_Drop_Rate': 0.2750056645728348, 'Data_Transfer_Rate': 429, 'Latency': 89, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_1', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:57:08', 'Signal_Strength': -77, 'Call_Drop_Rate': 0.7111124783884407, 'Data_Transfer_Rate': 828.2057992991738, 'Latency': 45, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_1', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 05:57:08', 'Signal_Strength': -77, 'Call_Drop_Rate': 0.7111124783884407, 'Data_Transfer_Rate': 828.2057992991738, 'Latency': 45, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:57:09', 'Signal_Strength': -38, 'Call_Drop_Rate': 0.1331188432537591, 'Data_Transfer_Rate': 714, 'Latency': 243, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:57:09', 'Signal_Strength': -38, 'Call_Drop_Rate': 0.1331188432537591, 'Data_Transfer_Rate': 714, 'Latency': 243, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:57:10', 'Signal_Strength': -83, 'Call_Drop_Rate': 0.6938540553045907, 'Data_Transfer_Rate': 223.26887553874744, 'Latency': 204, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:57:10', 'Signal_Strength': -83, 'Call_Drop_Rate': 0.6938540553045907, 'Data_Transfer_Rate': 223.26887553874744, 'Latency': 204, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_15', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:57:11', 'Signal_Strength': -77, 'Call_Drop_Rate': 0.9977015866567326, 'Data_Transfer_Rate': 249.38244649796644, 'Latency': 17, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_15', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:57:11', 'Signal_Strength': -77, 'Call_Drop_Rate': 0.9977015866567326, 'Data_Transfer_Rate': 249.38244649796644, 'Latency': 17, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_6', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:57:12', 'Signal_Strength': -45, 'Call_Drop_Rate': 0.9434214804747895, 'Data_Transfer_Rate': 626, 'Latency': 69, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_6', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:57:12', 'Signal_Strength': -45, 'Call_Drop_Rate': 0.9434214804747895, 'Data_Transfer_Rate': 626, 'Latency': 69, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_13', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:57:13', 'Signal_Strength': -88, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 651.6888055234276, 'Latency': 204, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_13', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:57:13', 'Signal_Strength': -88, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 651.6888055234276, 'Latency': 204, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:57:14', 'Signal_Strength': -32, 'Call_Drop_Rate': 0.9504131366429593, 'Data_Transfer_Rate': 450, 'Latency': 179, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:57:14', 'Signal_Strength': -32, 'Call_Drop_Rate': 0.9504131366429593, 'Data_Transfer_Rate': 450, 'Latency': 179, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_2', 'Timestamp': None, 'Signal_Strength': -45, 'Call_Drop_Rate': 0.20577161225597207, 'Data_Transfer_Rate': 597, 'Latency': 8, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_2', 'Timestamp': None, 'Signal_Strength': -45, 'Call_Drop_Rate': 0.20577161225597207, 'Data_Transfer_Rate': 597, 'Latency': 8, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:57:16', 'Signal_Strength': -69, 'Call_Drop_Rate': 0.6746294745111977, 'Data_Transfer_Rate': 830, 'Latency': 79, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:57:16', 'Signal_Strength': -69, 'Call_Drop_Rate': 0.6746294745111977, 'Data_Transfer_Rate': 830, 'Latency': 79, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:57:17', 'Signal_Strength': -94, 'Call_Drop_Rate': 0.5751655735121466, 'Data_Transfer_Rate': 262.70560225177115, 'Latency': 65, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:57:17', 'Signal_Strength': -94, 'Call_Drop_Rate': 0.5751655735121466, 'Data_Transfer_Rate': 262.70560225177115, 'Latency': 65, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_11', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:57:18', 'Signal_Strength': -110, 'Call_Drop_Rate': 0.543963033222179, 'Data_Transfer_Rate': 732.8287725781518, 'Latency': 142, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_11', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:57:18', 'Signal_Strength': -110, 'Call_Drop_Rate': 0.543963033222179, 'Data_Transfer_Rate': 732.8287725781518, 'Latency': 142, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_3', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:57:19', 'Signal_Strength': None, 'Call_Drop_Rate': 0.49001746502891186, 'Data_Transfer_Rate': 673, 'Latency': 57, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_3', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:57:19', 'Signal_Strength': None, 'Call_Drop_Rate': 0.49001746502891186, 'Data_Transfer_Rate': 673, 'Latency': 57, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:57:20', 'Signal_Strength': -104, 'Call_Drop_Rate': 0.6770529501621729, 'Data_Transfer_Rate': 119.25914630910279, 'Latency': 207, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 05:57:20', 'Signal_Strength': -104, 'Call_Drop_Rate': 0.6770529501621729, 'Data_Transfer_Rate': 119.25914630910279, 'Latency': 207, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_11', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:57:21', 'Signal_Strength': -105, 'Call_Drop_Rate': 0.4641512636892212, 'Data_Transfer_Rate': 783.1566617310291, 'Latency': 98, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_11', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 05:57:21', 'Signal_Strength': -105, 'Call_Drop_Rate': 0.4641512636892212, 'Data_Transfer_Rate': 783.1566617310291, 'Latency': 98, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_6', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:57:22', 'Signal_Strength': -80, 'Call_Drop_Rate': 0.7133240732722299, 'Data_Transfer_Rate': 681.0609020303039, 'Latency': 98, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_6', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 05:57:22', 'Signal_Strength': -80, 'Call_Drop_Rate': 0.7133240732722299, 'Data_Transfer_Rate': 681.0609020303039, 'Latency': 98, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:57:23', 'Signal_Strength': -34, 'Call_Drop_Rate': 0.7730197653335148, 'Data_Transfer_Rate': 477, 'Latency': 21, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 05:57:23', 'Signal_Strength': -34, 'Call_Drop_Rate': 0.7730197653335148, 'Data_Transfer_Rate': 477, 'Latency': 21, 'Location_ID': 'Location_1'}
# ...
# Sent data to Kafka: {'Customer_ID': 'Customer_12', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:28', 'Signal_Strength': -33, 'Call_Drop_Rate': 0.8017373709684835, 'Data_Transfer_Rate': 150, 'Latency': 180, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 06:20:29', 'Signal_Strength': -103, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 81.01052085914482, 'Latency': 134, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 06:20:29', 'Signal_Strength': -103, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 81.01052085914482, 'Latency': 134, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_12', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:30', 'Signal_Strength': -31, 'Call_Drop_Rate': 0.8775648223344131, 'Data_Transfer_Rate': 767, 'Latency': 46, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_12', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:30', 'Signal_Strength': -31, 'Call_Drop_Rate': 0.8775648223344131, 'Data_Transfer_Rate': 767, 'Latency': 46, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:31', 'Signal_Strength': -60, 'Call_Drop_Rate': 0.5898639879604903, 'Data_Transfer_Rate': 955, 'Latency': 131, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:31', 'Signal_Strength': -60, 'Call_Drop_Rate': 0.5898639879604903, 'Data_Transfer_Rate': 955, 'Latency': 131, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 06:20:32', 'Signal_Strength': -81, 'Call_Drop_Rate': 0.8385193915952887, 'Data_Transfer_Rate': 371.37445117714765, 'Latency': 160, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 06:20:32', 'Signal_Strength': -81, 'Call_Drop_Rate': 0.8385193915952887, 'Data_Transfer_Rate': 371.37445117714765, 'Latency': 160, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:33', 'Signal_Strength': -63, 'Call_Drop_Rate': None, 'Data_Transfer_Rate': None, 'Latency': 107, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:33', 'Signal_Strength': -63, 'Call_Drop_Rate': None, 'Data_Transfer_Rate': None, 'Latency': 107, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_14', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:34', 'Signal_Strength': -95, 'Call_Drop_Rate': 0.6378458655499422, 'Data_Transfer_Rate': 270.43463158028544, 'Latency': 165, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_14', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:34', 'Signal_Strength': -95, 'Call_Drop_Rate': 0.6378458655499422, 'Data_Transfer_Rate': 270.43463158028544, 'Latency': 165, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_5', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 06:20:35', 'Signal_Strength': -95, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 446.8126250432755, 'Latency': 201, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_5', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 06:20:35', 'Signal_Strength': -95, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 446.8126250432755, 'Latency': 201, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:36', 'Signal_Strength': -56, 'Call_Drop_Rate': 0.3070672083330608, 'Data_Transfer_Rate': 366, 'Latency': 220, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:36', 'Signal_Strength': -56, 'Call_Drop_Rate': 0.3070672083330608, 'Data_Transfer_Rate': 366, 'Latency': 220, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_8', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 06:20:37', 'Signal_Strength': -37, 'Call_Drop_Rate': 0.28510936214462335, 'Data_Transfer_Rate': 131, 'Latency': 159, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_8', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 06:20:37', 'Signal_Strength': -37, 'Call_Drop_Rate': 0.28510936214462335, 'Data_Transfer_Rate': 131, 'Latency': 159, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:38', 'Signal_Strength': -107, 'Call_Drop_Rate': 0.7972649583170724, 'Data_Transfer_Rate': 718.4487869790257, 'Latency': 21, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_16', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:38', 'Signal_Strength': -107, 'Call_Drop_Rate': 0.7972649583170724, 'Data_Transfer_Rate': 718.4487869790257, 'Latency': 21, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_3', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:39', 'Signal_Strength': -65, 'Call_Drop_Rate': 0.6169349503874195, 'Data_Transfer_Rate': 757, 'Latency': 72, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_3', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:39', 'Signal_Strength': -65, 'Call_Drop_Rate': 0.6169349503874195, 'Data_Transfer_Rate': 757, 'Latency': 72, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 06:20:40', 'Signal_Strength': None, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 255.3452790344087, 'Latency': 33, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 06:20:40', 'Signal_Strength': None, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 255.3452790344087, 'Latency': 33, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_12', 'Device_ID': 'Router_4', 'Timestamp': None, 'Signal_Strength': -51, 'Call_Drop_Rate': 0.11760931417851406, 'Data_Transfer_Rate': 430, 'Latency': 109, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_12', 'Device_ID': 'Router_4', 'Timestamp': None, 'Signal_Strength': -51, 'Call_Drop_Rate': 0.11760931417851406, 'Data_Transfer_Rate': 430, 'Latency': 109, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_14', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:42', 'Signal_Strength': None, 'Call_Drop_Rate': 0.7308277054132519, 'Data_Transfer_Rate': 559, 'Latency': 77, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_14', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:42', 'Signal_Strength': None, 'Call_Drop_Rate': 0.7308277054132519, 'Data_Transfer_Rate': 559, 'Latency': 77, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:43', 'Signal_Strength': -62, 'Call_Drop_Rate': 0.8411753821252405, 'Data_Transfer_Rate': 203, 'Latency': 36, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:43', 'Signal_Strength': -62, 'Call_Drop_Rate': 0.8411753821252405, 'Data_Transfer_Rate': 203, 'Latency': 36, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_13', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 06:20:44', 'Signal_Strength': -64, 'Call_Drop_Rate': 0.9272329503809629, 'Data_Transfer_Rate': 924, 'Latency': 203, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_13', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 06:20:44', 'Signal_Strength': -64, 'Call_Drop_Rate': 0.9272329503809629, 'Data_Transfer_Rate': 924, 'Latency': 203, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:45', 'Signal_Strength': -54, 'Call_Drop_Rate': 0.37203246732383444, 'Data_Transfer_Rate': 720, 'Latency': 181, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:45', 'Signal_Strength': -54, 'Call_Drop_Rate': 0.37203246732383444, 'Data_Transfer_Rate': 720, 'Latency': 181, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_11', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 06:20:46', 'Signal_Strength': -91, 'Call_Drop_Rate': 0.5322882951254737, 'Data_Transfer_Rate': 52.703194146726304, 'Latency': 13, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_11', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 06:20:46', 'Signal_Strength': -91, 'Call_Drop_Rate': 0.5322882951254737, 'Data_Transfer_Rate': 52.703194146726304, 'Latency': 13, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_7', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:47', 'Signal_Strength': None, 'Call_Drop_Rate': 0.30948745576580194, 'Data_Transfer_Rate': 827, 'Latency': 40, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_7', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:47', 'Signal_Strength': None, 'Call_Drop_Rate': 0.30948745576580194, 'Data_Transfer_Rate': 827, 'Latency': 40, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_5', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:48', 'Signal_Strength': None, 'Call_Drop_Rate': 0.7513623092957101, 'Data_Transfer_Rate': 90, 'Latency': 26, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_5', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:48', 'Signal_Strength': None, 'Call_Drop_Rate': 0.7513623092957101, 'Data_Transfer_Rate': 90, 'Latency': 26, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_3', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 06:20:49', 'Signal_Strength': -44, 'Call_Drop_Rate': 0.9099236828640567, 'Data_Transfer_Rate': 302, 'Latency': 247, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_3', 'Device_ID': 'Router_3', 'Timestamp': '2024-09-24 06:20:49', 'Signal_Strength': -44, 'Call_Drop_Rate': 0.9099236828640567, 'Data_Transfer_Rate': 302, 'Latency': 247, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 06:20:50', 'Signal_Strength': -46, 'Call_Drop_Rate': 0.7621577151080434, 'Data_Transfer_Rate': None, 'Latency': 121, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 06:20:50', 'Signal_Strength': -46, 'Call_Drop_Rate': 0.7621577151080434, 'Data_Transfer_Rate': None, 'Latency': 121, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:51', 'Signal_Strength': None, 'Call_Drop_Rate': 0.3765270335944968, 'Data_Transfer_Rate': 349, 'Latency': 171, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:51', 'Signal_Strength': None, 'Call_Drop_Rate': 0.3765270335944968, 'Data_Transfer_Rate': 349, 'Latency': 171, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_12', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:52', 'Signal_Strength': -98, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 31.866770542637994, 'Latency': 246, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_12', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:52', 'Signal_Strength': -98, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 31.866770542637994, 'Latency': 246, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_15', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 06:20:53', 'Signal_Strength': -109, 'Call_Drop_Rate': 0.6374991419035565, 'Data_Transfer_Rate': 205.8015362507506, 'Latency': 26, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_15', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 06:20:53', 'Signal_Strength': -109, 'Call_Drop_Rate': 0.6374991419035565, 'Data_Transfer_Rate': 205.8015362507506, 'Latency': 26, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_15', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 06:20:54', 'Signal_Strength': -81, 'Call_Drop_Rate': 0.49628657099050166, 'Data_Transfer_Rate': 522.8900982284857, 'Latency': 226, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_15', 'Device_ID': 'Router_5', 'Timestamp': '2024-09-24 06:20:54', 'Signal_Strength': -81, 'Call_Drop_Rate': 0.49628657099050166, 'Data_Transfer_Rate': 522.8900982284857, 'Latency': 226, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_9', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:55', 'Signal_Strength': -31, 'Call_Drop_Rate': 0.4215221265662401, 'Data_Transfer_Rate': None, 'Latency': 2, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_9', 'Device_ID': 'Router_4', 'Timestamp': '2024-09-24 06:20:55', 'Signal_Strength': -31, 'Call_Drop_Rate': 0.4215221265662401, 'Data_Transfer_Rate': None, 'Latency': 2, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:56', 'Signal_Strength': -102, 'Call_Drop_Rate': 0.8815201830365491, 'Data_Transfer_Rate': 805.6936168946546, 'Latency': 233, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_17', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:56', 'Signal_Strength': -102, 'Call_Drop_Rate': 0.8815201830365491, 'Data_Transfer_Rate': 805.6936168946546, 'Latency': 233, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_5', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:57', 'Signal_Strength': -80, 'Call_Drop_Rate': 0.7734936730300487, 'Data_Transfer_Rate': 704.0865940025417, 'Latency': 221, 'Location_ID': 'Location_1'}
# Sent data to Kafka: {'Customer_ID': 'Customer_5', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:20:57', 'Signal_Strength': -80, 'Call_Drop_Rate': 0.7734936730300487, 'Data_Transfer_Rate': 704.0865940025417, 'Latency': 221, 'Location_ID': 'Location_1'}
# {'Customer_ID': 'Customer_19', 'Device_ID': 'Router_3', 'Timestamp': None, 'Signal_Strength': -34, 'Call_Drop_Rate': 0.9750376815426618, 'Data_Transfer_Rate': 378, 'Latency': 81, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_19', 'Device_ID': 'Router_3', 'Timestamp': None, 'Signal_Strength': -34, 'Call_Drop_Rate': 0.9750376815426618, 'Data_Transfer_Rate': 378, 'Latency': 81, 'Location_ID': 'Location_2'}
# {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 06:20:59', 'Signal_Strength': None, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 623.0401230721419, 'Latency': 119, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_2', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 06:20:59', 'Signal_Strength': None, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 623.0401230721419, 'Latency': 119, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 06:21:00', 'Signal_Strength': -44, 'Call_Drop_Rate': 0.6044163931300751, 'Data_Transfer_Rate': 173, 'Latency': 248, 'Location_ID': 'Location_3'}
# Sent data to Kafka: {'Customer_ID': 'Customer_18', 'Device_ID': 'Router_2', 'Timestamp': '2024-09-24 06:21:00', 'Signal_Strength': -44, 'Call_Drop_Rate': 0.6044163931300751, 'Data_Transfer_Rate': 173, 'Latency': 248, 'Location_ID': 'Location_3'}
# {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:21:01', 'Signal_Strength': -75, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 44.98524031594627, 'Latency': 157, 'Location_ID': 'Location_2'}
# Sent data to Kafka: {'Customer_ID': 'Customer_10', 'Device_ID': 'Router_1', 'Timestamp': '2024-09-24 06:21:01', 'Signal_Strength': -75, 'Call_Drop_Rate': 1, 'Data_Transfer_Rate': 44.98524031594627, 'Latency': 157, 'Location_ID': 'Location_2'}
# Live data generation stopped.
